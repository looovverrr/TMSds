# %%
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn as sns
img = plt.imread("image.jpg")
plt.imshow(img)

# %%
data = img.copy()
data[data > 100] = 200
plt.imshow(data)

# %%
data = img.copy()
data[data > 230] = 0
plt.imshow(data)

# %%
imgg = plt.imread("renee.jpg")
plt.imshow(imgg)

# %%
dataa = imgg.copy()
dataa[dataa >150] =0
plt.imshow(dataa)

# %%
titanic= pd.read_csv("train.csv")

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
matrix=titanic.corr()

# %%
sns.heatmap(matrix)
# Out:
# <AxesSubplot:>

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Embarked', y='Fare', data=titanic)
plt.title('Сопоставление стоимости билетов и порта посадки')
plt.xlabel('Порт посадки')
plt.ylabel('Стоимость билета')
# Out:
# Text(0, 0.5, 'Стоимость билета')

# %%
titanic['Age'] = pd.cut(titanic['Age'], bins=[0, 30, 50, 80], labels=["молодой", "взрослый","пожилой"], include_lowest=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male   молодой
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  взрослый
# 2                               Heikkinen, Miss. Laina  female   молодой
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  взрослый
# 4                             Allen, Mr. William Henry    male  взрослый
# ..                                                 ...     ...       ...
# ...

# %%
supr_par= titanic.query("SibSp==1")
supr_par
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 10            11         1       3
# ..           ...       ...     ...
# 866          867         1       2
# 869          870         1       3
# 871          872         1       1
# 874          875         1       2
# 888          889         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male   молодой
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  взрослый
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  взрослый
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   молодой
# 10                     Sandstrom, Miss. Marguerite Rut  female   молодой
# ..                                                 ...     ...       ...
# ...

# %%
deti_rod=titanic.query("Parch>0")
deti_rod
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# ..           ...       ...     ...
# 871          872         1       1
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex       Age  \
# 7                       Palsson, Master. Gosta Leonard    male   молодой
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   молодой
# 10                     Sandstrom, Miss. Marguerite Rut  female   молодой
# 13                         Andersson, Mr. Anders Johan    male  взрослый
# 16                                Rice, Master. Eugene    male   молодой
# ..                                                 ...     ...       ...
# ...

# %%
brat_sestra= titanic.query("SibSp>0")
brat_sestra
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 869          870         1       3
# 871          872         1       1
# 874          875         1       2
# 888          889         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male   молодой
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  взрослый
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  взрослый
# 7                       Palsson, Master. Gosta Leonard    male   молодой
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   молодой
# ..                                                 ...     ...       ...
# ...
