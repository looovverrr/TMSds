# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df= pd.read_csv("timesData.csv")

# %% [markdown]
# ## world_rank: мировое место университета.
# ## university_name: название университета.
# ## country: страна, в которой расположен университет.
# ## teaching: оценка университета в области обучения.
# ## international: оценка университета в международном измерении.
# ## research: оценка университета в области исследований.
# ## citations: количество цитирований университета.
# ## income: доход университета.
# ## total_score: общая оценка университета.
# ## num_students: количество студентов в университете.
# ## student_staff_ratio: соотношение студентов к сотрудникам.
# ## international_students: процент международных студентов.
# ## female_male_ratio: соотношение женщин к мужчинам.
# ## year: год оценки университета.

# %%
df.columns
# Out:
# Index(['world_rank', 'university_name', 'country', 'teaching', 'international',
#        'research', 'citations', 'income', 'total_score', 'num_students',
#        'student_staff_ratio', 'international_students', 'female_male_ratio',
#        'year'],
#       dtype='object')

# %%
plt.style.use('grayscale')
plt.figure(figsize=(20,10))
sns.countplot(data=df,y='country')                           
plt.title('Количество университетов для каждой страны',fontsize=40)            
plt.ylabel('Count',fontsize=25)                                     
plt.show()

# %% [markdown]
# ## Можно сделать выводы что наибольшее количество вузов находятся в США

# %%
plt.style.use('Solarize_Light2')
matrix=df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(matrix,annot=True, cmap='coolwarm', fmt=".2f", linewidths=.9)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (2603, 14)

# %%
df.isnull().sum()
# Out:
# world_rank                  0
# university_name             0
# country                     0
# teaching                    0
# international               0
# research                    0
# citations                   0
# income                      0
# total_score                 0
# num_students               59
# student_staff_ratio        59
# international_students     67
# female_male_ratio         233
# year                        0
# dtype: int64

# %%
df.head(5,)
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
df['female_male_ratio'].unique()
# Out:
# array([nan, '33 : 67', '37 : 63', '42 : 58', '45 : 55', '46 : 54',
#        '50 : 50', '52 : 48', '48 : 52', '31 : 69', '51 : 49', '39 : 61',
#        '53 : 47', '56 : 44', '49 : 51', '20 : 80', '54 : 46', '58 : 42',
#        '47 : 53', '55 : 45', '18 : 82', '70 : 30', '44 : 56', '27 : 73',
#        '32 : 68', '62 : 38', '57 : 43', '61 : 39', '66 : 34', '30 : 70',
#        '13 : 87', '19 : 81', '59 : 41', '25 : 75', '60 : 40', '26 : 74',
#        '67 : 33', '41 : 59', '63 : 37', '29 : 71', '35 : 65', '28 : 72',
#        '65 : 35', '38 : 62', '34 : 66', '43 : 57', '16 : 84', '64 : 36',
#        '36 : 64', '12 : 88', '15 : 85', '17 : 83', '24 : 76', '100 : 0',
#        '40 : 60', '77 : 23', '71 : 29', '69 : 31', '22 : 78', '23 : 77',
#        '-', '14 : 86', '78 : 22', '76 : 24', '21 : 79', '11 : 89',
#        '68 : 32', '1 : 99', '74 : 26', '9 : 91'], dtype=object)

# %%
df[df['female_male_ratio'] == '100 : 0']
# Out:
#      world_rank         university_name      country  teaching international  \
# 1760    351-400  Ewha Womans University  South Korea      23.5          36.0
# 2227    401-500  Ewha Womans University  South Korea      23.9          34.3
#
#       research  citations income total_score num_students  \
# 1760      18.0       57.6   61.3           -       17,625
# 2227      18.3       50.4   57.6           -       17,625
#
#       student_staff_ratio international_students female_male_ratio  year
# 1760                 14.4                     6%           100 : 0  2015
# 2227                 14.4                     6%           100 : 0  2016

# %% [markdown]
# # прикольно, есть чисто женские университеты :)

# %%
df['female_male_ratio'] = df['female_male_ratio'].replace({
   '33 : 67':'парней значительно больше', 
    '37 : 63':'парней значительно больше', 
    '42 : 58':'парней больше', 
    '45 : 55':'приблизительно одинаково',
    '46 : 54':'приблизительно одинаково',
    '50 : 50':'одинаково', 
    '52 : 48':'девушек чуть больше', 
    '48 : 52':'парней чуть больше', 
    '31 : 69':'парней значительно больше', 
    '51 : 49':'приблизительно одинаково',
    '46 : 54':'приблизительно одинаково',
    '39 : 61':'парней значительно больше',
    '46 : 54':'приблизительно одинаково',
    '47 : 53':'приблизительно одинаково',
    '55 : 45':'приблизительно одинаково',
    '18 : 82':'парней значительно больше',
    '70 : 30':'девушек значительно больше', 
    '44 : 56':'приблизительно одинаково',
    '27 : 73':'парней значительно больше', 
    '32 : 68':'парней значительно больше', 
    '62 : 38':'девушек значительно больше',
    '57 : 43':'приблизительно одинаково',
    '61 : 39':'девушек значительно больше',
    '66 : 34':'девушек значительно больше',
    '30 : 70':'парней значительно больше', 
    '13 : 87':'парней значительно больше', 
    '19 : 81':'парней значительно больше', 
    '59 : 41':'приблизительно одинаково',
    '25 : 75':'парней значительно больше',
    '60 : 40':'девушек значительно больше',
    '26 : 74':'девушек значительно больше',
    '67 : 33':'девушек значительно больше',
    '41 : 59':'приблизительно одинаково',
    '63 : 37':'девушек значительно больше',
    '29 : 71':'парней значительно больше', 
    '35 : 65':'парней значительно больше', 
    '28 : 72':'парней значительно больше', 
    '65 : 35':'девушек значительно больше',
    '38 : 62':'парней значительно больше', 
    '34 : 66':'парней значительно больше', 
    '43 : 57':'приблизительно одинаково',
    '16 : 84':'парней значительно больше', 
    '64 : 36':'девушек значительно больше',
    '36 : 64':'парней значительно больше', 
    '12 : 88':'парней значительно больше', 
    '15 : 85':'парней значительно больше', 
    '17 : 83':'парней значительно больше', 
    '24 : 76':'парней значительно больше', 
    '100 : 0':'исключительно девушки',
    '40 : 60' :'парней значительно больше', 
    '77 : 23':'девушек значительно больше',
    '71 : 29':'девушек значительно больше',
    '69 : 31':'девушек значительно больше',
    '22 : 78':'парней значительно больше', 
    '23 : 77':'парней значительно больше', 
    '-':'нет данных',
    '14 : 86':'парней значительно больше', 
    '78 : 22':'девушек значительно больше',
    '76 : 24':'девушек значительно больше',
    '21 : 79':'парней значительно больше', 
    '11 : 89':'парней значительно больше', 
    '68 : 32':'девушек значительно больше',
    '1 : 99':'парней значительно больше', 
    '74 : 26':'девушек значительно больше',
    '9 : 91':'парней значительно больше',
    '53 : 47':'приблизительно одинаково',
    '56 : 44':'приблизительно одинаково',
    '49 : 51':'приблизительно одинаково',
    '20 : 80':'парней значительно больше',
    '54 : 46':'приблизительно одинаково',
    '58 : 42':'приблизительно одинаково',
})

# %% [markdown]
# # тут я решила изменить соотношения в более удобный формат

# %% [markdown]
# ## Разделение по годам

# %%
df["year"].value_counts()
# Out:
# 2016    800
# 2012    402
# 2015    401
# 2013    400
# 2014    400
# 2011    200
# Name: year, dtype: int64

# %%
top_30= df.head(30)
top_30.head(5,)
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# # топ 5 вузов 2011 года

# %%
year_2012=df.iloc[200:601].copy()
year_2012.head(5,)
# Out:
#     world_rank                     university_name                   country  \
# 200          1  California Institute of Technology  United States of America
# 201          2                  Harvard University  United States of America
# 202          2                 Stanford University  United States of America
# 203          4                University of Oxford            United Kingdom
# 204          5                Princeton University  United States of America
#
#      teaching international  research  citations income total_score  \
# 200      95.7          56.0      98.2       99.9   97.0        94.8
# 201      95.8          67.5      97.4       99.8   35.9        93.9
# 202      94.8          57.2      98.9       99.8   63.8        93.9
# 203      89.5          91.9      96.6       97.9   62.1        93.6
# 204      91.5          49.6      99.1      100.0   81.0        92.9
#
#     num_students  student_staff_ratio international_students  \
# ...

# %% [markdown]
# # топ 5 вузов 2012 года

# %%
year_2013=df.iloc[602:1001].copy()
year_2013.head(5,)
# Out:
#     world_rank                        university_name  \
# 602          1     California Institute of Technology
# 603          2                    Stanford University
# 604          2                   University of Oxford
# 605          4                     Harvard University
# 606          5  Massachusetts Institute of Technology
#
#                       country  teaching international  research  citations  \
# 602  United States of America      96.3          59.8      99.4       99.7
# 603  United States of America      95.0          56.6      98.8       99.3
# 604            United Kingdom      89.7          88.7      98.1       95.6
# 605  United States of America      94.9          63.7      98.6       99.2
# 606  United States of America      92.9          81.6      89.2       99.9
#
#     income total_score num_students  student_staff_ratio  \
# 602   95.6        95.5        2,243                  6.9
# 603   62.4        93.7       15,596                  7.8
# ...

# %% [markdown]
# # и остальных лет

# %%
year_2014=df.iloc[1002:1401].copy()
year_2014.head(5,)
# Out:
#      world_rank                        university_name  \
# 1002          1     California Institute of Technology
# 1003          2                     Harvard University
# 1004          2                   University of Oxford
# 1005          4                    Stanford University
# 1006          5  Massachusetts Institute of Technology
#
#                        country  teaching international  research  citations  \
# 1002  United States of America      94.4          65.8      98.2       99.8
# 1003  United States of America      95.3          66.2      98.5       99.1
# 1004            United Kingdom      89.0          90.2      98.5       95.4
# 1005  United States of America      94.7          68.0      96.8       99.1
# 1006  United States of America      92.9          82.0      89.0      100.0
#
#      income total_score num_students  student_staff_ratio  \
# 1002   91.2        94.9        2,243                  6.9
# ...

# %%
year_2015=df.iloc[1402:1802].copy()
year_2015.head(5,)
# Out:
#      world_rank                     university_name                   country  \
# 1402          1  California Institute of Technology  United States of America
# 1403          2                  Harvard University  United States of America
# 1404          3                University of Oxford            United Kingdom
# 1405          4                 Stanford University  United States of America
# 1406          5             University of Cambridge            United Kingdom
#
#       teaching international  research  citations income total_score  \
# 1402      92.2          67.0      98.1       99.7   89.1        94.3
# 1403      92.9          67.6      98.6       98.9   44.0        93.3
# 1404      88.6          90.7      97.7       95.5   72.9        93.2
# 1405      91.5          69.0      96.7       99.1   63.1        92.9
# 1406      89.7          87.8      95.6       95.2   51.1        92.0
#
#      num_students  student_staff_ratio international_students  \
# ...

# %%
year_2016=df.iloc[1803:2602].copy()
year_2016.head(5,)
# Out:
#      world_rank                        university_name  \
# 1803          1     California Institute of Technology
# 1804          2                   University of Oxford
# 1805          3                    Stanford University
# 1806          4                University of Cambridge
# 1807          5  Massachusetts Institute of Technology
#
#                        country  teaching international  research  citations  \
# 1803  United States of America      95.6          64.0      97.6       99.8
# 1804            United Kingdom      86.5          94.4      98.9       98.8
# 1805  United States of America      92.5          76.3      96.2       99.9
# 1806            United Kingdom      88.2          91.5      96.7       97.0
# 1807  United States of America      89.4          84.0      88.6       99.7
#
#      income total_score num_students  student_staff_ratio  \
# 1803   97.8        95.2        2,243                  6.9
# ...

# %% [markdown]
# # интересно,что к 2016 году гарвард вообще не входит в 5 лучших, с чем это связано?

# %%
df[df["university_name"]=="Harvard University"]
# Out:
#      world_rank     university_name                   country  teaching  \
# 0             1  Harvard University  United States of America      99.7
# 201           2  Harvard University  United States of America      95.8
# 605           4  Harvard University  United States of America      94.9
# 1003          2  Harvard University  United States of America      95.3
# 1403          2  Harvard University  United States of America      92.9
# 1808          6  Harvard University  United States of America      83.6
#
#      international  research  citations income total_score num_students  \
# 0             72.4      98.7       98.8   34.5        96.1       20,152
# 201           67.5      97.4       99.8   35.9        93.9       20,152
# 605           63.7      98.6       99.2   39.9        93.6       20,152
# 1003          66.2      98.5       99.1   40.6        93.9       20,152
# 1403          67.6      98.6       98.9   44.0        93.3       20,152
# ...

# %% [markdown]
# # упала оценка в области обучения плюз много интернациональных студентов, наверное вот и причина. зато California Institute of Technology с 2012-2016 года стабильно занимает 1 место

# %%
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=top_30,y="country")
plt.title("Страны с самыми лучшими вузами в 2011", fontsize=20,color="black")
plt.show()

# %%
top_30_1=year_2012.head(30)
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=top_30_1,y="country")
plt.title("Страны с самыми лучшими вузами в 2012", fontsize=20,color="black")
plt.show()

# %% [markdown]
# # место северной кореи заняла япония

# %%
top_30_2=year_2013.head(30)
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=top_30_2,y="country")
plt.title("Страны с самыми лучшими вузами в 2013", fontsize=20,color="black")
plt.show()

# %% [markdown]
# # а тут уже австралия и сингапур

# %%
top_3_4=year_2014.head(30)
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=top_3_4,y="country")
plt.title("Страны с самыми лучшими вузами в 2014", fontsize=20,color="black")
plt.show()

# %%
top_3_5=year_2015.head(30)
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=top_3_5,y="country")
plt.title("Страны с самыми лучшими вузами в 2015", fontsize=20,color="black")
plt.show()

# %% [markdown]
# # появилась германия

# %%
top_3_5=year_2016.head(30)
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=top_3_5,y="country")
plt.title("Страны с самыми лучшими вузами в 2016", fontsize=20,color="black")
plt.show()

# %% [markdown]
# # а теперь и швеция, значит европа развивается, ура

# %%
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=top_30,y="female_male_ratio")
plt.title("соотношение парней и девушек в топовых вузах 2011 год ", fontsize=20,color="black")
plt.show()

# %%
plt.style.use('grayscale')
plt.figure(figsize=(20,20))
sns.countplot(data=year_2016,y="female_male_ratio")
plt.title("соотношение парней и девушек в топовых вузах 2016 год ", fontsize=20,color="black")
plt.show()

# %% [markdown]
# # сделала графики для 2011 и 2016 для лучших вузов и зависимости пола и тут видно, что пол никак не влияет на уровень университета! а к 2016 году графа девушек значительно больше вообще выросла, интересное наблюдение

# %% [markdown]
# # неожиданно

# %%
df[df["country"]=="Belarus"]
# Out:
#      world_rank              university_name  country  teaching international  \
# 2422    601-800  Belarusian State University  Belarus      20.2          48.2
#
#       research  citations income total_score num_students  \
# 2422       8.7        6.0   28.0           -       29,303
#
#       student_staff_ratio international_students           female_male_ratio  \
# 2422                 10.6                     6%  девушек значительно больше
#
#       year
# 2422  2016

# %%
df.describe()
# Out:
#           teaching     research    citations  student_staff_ratio         year
# count  2603.000000  2603.000000  2603.000000          2544.000000  2603.000000
# mean     37.801498    35.910257    60.921629            18.445283  2014.075682
# std      17.604218    21.254805    23.073219            11.458698     1.685733
# min       9.900000     2.900000     1.200000             0.600000  2011.000000
# 25%      24.700000    19.600000    45.500000            11.975000  2013.000000
# 50%      33.900000    30.500000    62.500000            16.100000  2014.000000
# 75%      46.400000    47.250000    79.050000            21.500000  2016.000000
# max      99.700000    99.400000   100.000000           162.600000  2016.000000

# %% [markdown]
# # моя первая выборка это каждый 5 элемент

# %%
sample1=df[::5]
print(sample1.shape)
print(sample1.describe())
sample1.hist(figsize=(20, 10), color='skyblue', bins=10, alpha=0.9)
# Out:
# (521, 14)
#          teaching    research   citations  student_staff_ratio         year
# count  521.000000  521.000000  521.000000           506.000000   521.000000
# mean    37.595777   36.208637   61.019002            19.466601  2014.072937
# std     17.971103   21.704763   22.414152            12.144520     1.687755
# min      9.900000    3.700000    3.100000             1.100000  2011.000000
# 25%     23.600000   19.100000   45.700000            12.925000  2013.000000
# 50%     33.700000   30.200000   62.200000            16.250000  2014.000000
# 75%     46.200000   48.100000   78.300000            22.875000  2016.000000
# max     99.700000   99.300000  100.000000            85.800000  2016.000000
# array([[<AxesSubplot:title={'center':'teaching'}>,
#         <AxesSubplot:title={'center':'research'}>],
#        [<AxesSubplot:title={'center':'citations'}>,
#         <AxesSubplot:title={'center':'student_staff_ratio'}>],
# ...

# %% [markdown]
# # вторая выборка это рандомные 80 из каждого года

# %%
sample2 = pd.concat([df.sample(n=100, replace=True) for df in [top_30, year_2012, year_2013, year_2014, year_2015, year_2016]])
print(sample2.shape)
print(sample2.describe())
sample2.hist(figsize=(20, 10), color='skyblue', bins=10, alpha=0.9)
# Out:
# (600, 14)
#          teaching    research   citations  student_staff_ratio        year
# count  600.000000  600.000000  600.000000           594.000000   600.00000
# mean    44.224500   43.875167   67.548333            17.457576  2013.50000
# std     22.519887   26.226845   23.182567            11.151052     1.70925
# min      9.900000    7.700000    7.600000             2.900000  2011.00000
# 25%     26.525000   22.400000   51.025000            10.225000  2012.00000
# 50%     37.300000   35.150000   70.050000            15.700000  2013.50000
# 75%     56.850000   65.250000   87.600000            20.200000  2015.00000
# max     99.700000   99.300000  100.000000            88.900000  2016.00000
# array([[<AxesSubplot:title={'center':'teaching'}>,
#         <AxesSubplot:title={'center':'research'}>],
#        [<AxesSubplot:title={'center':'citations'}>,
#         <AxesSubplot:title={'center':'student_staff_ratio'}>],
#        [<AxesSubplot:title={'center':'year'}>, <AxesSubplot:>]],
# ...

# %% [markdown]
# # просто рандомные 600

# %%
sample3 = df.sample(n=600)
print(sample3.shape)
print(sample3.describe())
sample3.hist(figsize=(20, 10), color='skyblue', bins=10, alpha=0.9)
# Out:
# (600, 14)
#          teaching    research   citations  student_staff_ratio         year
# count  600.000000  600.000000  600.000000           587.000000   600.000000
# mean    37.603167   35.740167   61.413000            18.545315  2014.078333
# std     17.396091   21.244014   23.114232            11.277837     1.728345
# min      9.900000    2.900000    3.100000             2.100000  2011.000000
# 25%     24.500000   19.300000   45.275000            11.900000  2013.000000
# 50%     33.950000   30.150000   64.400000            16.400000  2014.000000
# 75%     46.425000   47.725000   79.475000            21.750000  2016.000000
# max     97.700000   99.400000  100.000000            85.800000  2016.000000
# array([[<AxesSubplot:title={'center':'teaching'}>,
#         <AxesSubplot:title={'center':'research'}>],
#        [<AxesSubplot:title={'center':'citations'}>,
#         <AxesSubplot:title={'center':'student_staff_ratio'}>],
# ...

# %% [markdown]
# # выборка где соотношение девушек и парней +- одинаковое

# %%
sample4_1 = df[df['female_male_ratio'] == 'одинаково']
sample4_2 = df[df['female_male_ratio'] == 'приблизительно одинаково']
sample4 = pd.concat([sample4_1, sample4_2])
print(sample4.shape)
print(sample4.describe())
sample4.hist(figsize=(20, 10), color='skyblue', bins=10, alpha=0.9)
# Out:
# (1367, 14)
#           teaching     research    citations  student_staff_ratio         year
# count  1367.000000  1367.000000  1367.000000          1367.000000  1367.000000
# mean     37.149159    35.324799    63.202268            19.511192  2014.024872
# std      16.312225    19.906484    21.666900            11.013121     1.671647
# min      10.800000     2.900000     1.700000             2.500000  2011.000000
# 25%      25.600000    20.650000    49.550000            13.450000  2013.000000
# 50%      33.700000    30.500000    64.500000            17.300000  2014.000000
# 75%      45.100000    45.950000    80.300000            22.400000  2016.000000
# max      93.200000    99.400000   100.000000            88.900000  2016.000000
# array([[<AxesSubplot:title={'center':'teaching'}>,
#         <AxesSubplot:title={'center':'research'}>],
#        [<AxesSubplot:title={'center':'citations'}>,
#         <AxesSubplot:title={'center':'student_staff_ratio'}>],
# ...

# %% [markdown]
# # выборка вуза по странам европы

# %%
european_countries = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czech Republic', 
                      'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 
                      'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 
                      'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 
                      'United Kingdom']

sample5 = df[df['country'].isin(european_countries)]
print(sample5.shape)
print(sample5.describe())
sample1.hist(figsize=(20, 10), color='skyblue', bins=10, alpha=0.9)
# Out:
# (1015, 14)
#           teaching     research    citations  student_staff_ratio         year
# count  1015.000000  1015.000000  1015.000000           999.000000  1015.000000
# mean     33.891724    32.441675    62.805616            21.943343  2014.068966
# std      14.408565    18.308307    19.131604            13.856253     1.666225
# min      12.200000     2.900000     6.800000             2.900000  2011.000000
# 25%      23.400000    18.500000    50.750000            14.000000  2013.000000
# 50%      31.100000    28.000000    64.500000            17.200000  2014.000000
# 75%      40.400000    43.800000    76.900000            24.950000  2016.000000
# max      91.200000    98.900000   100.000000            88.900000  2016.000000
# array([[<AxesSubplot:title={'center':'teaching'}>,
#         <AxesSubplot:title={'center':'research'}>],
#        [<AxesSubplot:title={'center':'citations'}>,
#         <AxesSubplot:title={'center':'student_staff_ratio'}>],
# ...

# %% [markdown]
# # В целом, можно сказать, что пяти выборки имеют схожие характеристики в области образования, исследований, цитирования и соотношения сотрудников и студентов.

# %% [markdown]
# # результаты у каждой +- одинаковые и неплохие. но мне кажется лучшей была 2 выборка, где 80 с каждого года
